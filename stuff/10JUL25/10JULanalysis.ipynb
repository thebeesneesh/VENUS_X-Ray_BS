# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('09JUL25use.csv')

plt.scatter(df['Total Power'], df['Spectral Temperature'])
plt.xlabel('Total Power (W)')
plt.ylabel('Spectral Temperature (eV)')
plt.title('Power vs Ts')
plt.show()
